# %%
import pandas as pd

# %%
Data = {
    "name" : ["Sarvesh" ,"Dhanu" ,"Pranav" ,"Sushil" ,"Tejas"
             ,"Bhushan" , "Vishal" ,'Sanket' ,'yash',"Sakshi" ],
    
    "age" : [20 , 20 , 27 , 21,25,
             23,26,31,52,22],
    
    "city" : ["pune" ,"jalgaon" ,'parbhani' , "Jalgaon" , 'Latur'
             , "pune" , "Mumbai" ,"delhi" , "bhopal" , 'bhusaval'] ,
    
    "id" : [101,102,103,104,105
           ,106,107,108,109,110]
}

DF = pd.DataFrame (Data)

# %%
DF
# Out:
#       name  age      city   id
# 0  Sarvesh   20      pune  101
# 1    Dhanu   20   jalgaon  102
# 2   Pranav   27  parbhani  103
# 3   Sushil   21   Jalgaon  104
# 4    Tejas   25     Latur  105
# 5  Bhushan   23      pune  106
# 6   Vishal   26    Mumbai  107
# 7   Sanket   31     delhi  108
# 8     yash   52    bhopal  109
# 9   Sakshi   22  bhusaval  110

# %%
DF.to_excel ("Student1.xlsx" , index = False)
