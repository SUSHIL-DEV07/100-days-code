# %%
D = {
    'yash' : 55 ,
    'suraj' : 76 , 
    'Sumit' : 90 , 
    'Pranav' : 76 
}

# %%
D
# Out:
# {'yash': 55, 'suraj': 76, 'Sumit': 90, 'Pranav': 76}

# %%
max (D) # not get Alphabatal return
# Out:
# 'yash'

# %%
max (D , key = D.get)
# Out:
# 'Sumit'

# %%
x , y = max(i,x for i,x in D.items ())
# Out:
#   Cell In[13], line 1
#     x , y = max(i,x for i,x in D.items ())
#                   ^
# SyntaxError: Generator expression must be parenthesized

# %%
x
# Out:
# 'yash'
